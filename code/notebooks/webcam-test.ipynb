# %% [markdown]
# # Simple Webcam test

# %%
from functions import *

# %%
fpath = saveWebcamImage(path=WEBCAM_PATH)
displayFile(fpath)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0xB4325B90>

# %%
frame = getWebcamImage(show=True)
